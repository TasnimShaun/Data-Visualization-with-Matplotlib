# %% [markdown]
# <a href="https://colab.research.google.com/github/TasnimShaun/Data-Visualization-with-Matplotlib/blob/main/AI_Programming_With_Python_Final_Exam_Answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Programming with Python Final Exam
#
# **Name: Your Name**
#
# **Course Email:**  youremail@gmail.com
#
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # 0) Starter Code (Run First)

# %%
# You must run this code and use this dataset for all questions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
num_students = 50

# Student data
student_ids = np.arange(201, 201 + num_students)
student_ages = np.random.randint(15, 22, num_students)
student_scores = np.random.randint(40, 100, num_students)
student_attendance = np.random.randint(60, 100, num_students)  # percentage

departments_list = [
    "Science",
    "Commerce",
    "Arts",
    "Computer Science",
    "Mathematics",
    "English",
    "Physics",
    "Chemistry",
    "Biology",
    "Economics"
]

student_departments = np.random.choice(departments_list, num_students)

grade_conditions = [
    student_scores >= 80,
    (student_scores >= 65) & (student_scores < 80),
    (student_scores >= 50) & (student_scores < 65),
    student_scores < 50
]
grade_values = ["A", "B", "C", "F"]
student_grades = np.select(grade_conditions, grade_values, default="F")

# Create DataFrame
data = pd.DataFrame({
    "student_id": student_ids,
    "student_age": student_ages,
    "score": student_scores,
    "attendance": student_attendance,
    "department": student_departments,
    "grade": student_grades
})

# Save dataset
data.to_csv("school_data.csv", index=False)

# %% [markdown]
# Name: MD TASNIMUL HASAN
# Course Email: tasnimshaun3@gmail.com

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# Use NumPy arrays from the score and attendance columns. Print both arrays and display:
#
# * Data type
# * Number of dimensions
# * Shape
# * Total number of elements

# %% [markdown]
# # Write Answer 01:

# %%
import numpy as np
score = np.array(data['score'])
attendance = np.array(data['attendance'])
print(f"students score array:{score}")
print()
print(f"students attendance array:{attendance}")
# Out:
# students score array:[76 90 46 60 48 78 57 43 64 99 53 89 97 48 65 92 41 59 67 86 99 46 83 47
#  86 74 53 56 75 89 79 43 41 45 93 81 43 93 68 57 65 83 73 49 75 53 70 87
#  54 47]
#
# students attendance array:[73 82 99 80 75 77 83 85 84 88 74 60 84 66 68 83 60 67 83 70 76 67 94 94
#  92 64 98 87 66 68 67 71 93 92 82 83 96 94 99 81 86 94 60 94 96 73 62 60
#  64 85]

# %%
# students score
print("students score information:")
print("data type:",student_scores.dtype)
print(f"dimention:{student_scores.ndim}D ")
print("shape:",student_scores.shape)
print("total number of elements:",student_scores.size)

print()

# students attendance information
print(" students attendance information:")
print("data type:",student_attendance.dtype)
print("shape:",student_attendance.shape)
print(f"dimention:{student_attendance.ndim}D ")
print("total number of elements:",student_attendance.size)
# Out:
# students score information:
# data type: int64
# dimention:1D
# shape: (50,)
# total number of elements: 50
#
#  students attendance information:
# data type: int64
# shape: (50,)
# dimention:1D
# total number of elements: 50

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# ## Using NumPy functions on :
#
# * Find the maximum and minimum score
# * Calculate the average score
# * Calculate the average attendance
#
# Then, extract students who:
#
# * Have a score greater than the average score
#
# Print:
#
# * The filtered score array

# %% [markdown]
# ## Write Answer 02:

# %%
# maximum score and minimum score

maximum_score = np.max(student_scores)
minimum_score = np.min(student_scores)

# average score

average_score = np.mean(student_scores)

# average attendance
average_attendance = np.mean(student_attendance)

print("Maximum Score:", maximum_score)
print("Minimum Score:", minimum_score)
print("Average Score:", average_score)
print("Average Attendance:", average_attendance)
# Out:
# Maximum Score: 99
# Minimum Score: 41
# Average Score: 67.3
# Average Attendance: 79.58

# %%
students_whose_score = student_scores[(student_scores > average_score)]
print()
print("filtered score array:")
print(students_whose_score)

count = students_whose_score.shape[0] # optional
print(f"Number of students whose scores are greater than the average score:{count}")
# Out:
# filtered score array:
# [76 90 78 99 89 97 92 86 99 83 86 74 75 89 79 93 81 93 68 83 73 75 70 87]
# Number of students whose scores are greater than the average score:24

# %% [markdown]
# # Question 03: [Marks 10]
#
# ##
# Load the school_data.csv file into a Pandas DataFrame.
#
# * Display the first 3 rows
# * Show dataset information using .info()
# * Display summary statistics using .describe()
#
# Then filter the dataset to include only:
#
# * student_id, student_age, department, grade
#
# Select students whose age is between 16 and 20, sort them by student_id, and display the last 3 rows of the result.

# %% [markdown]
# ## Write Answer 03:

# %%
import pandas as pd
df = pd.read_csv("/content/school_data.csv")
print(df.head(3))
print()
print(df.describe())
print()
print(df.info())
# Out:
#    student_id  student_age  score  attendance department grade
# 0         201           21     76          73    Physics     B
# 1         202           18     90          82    Physics     A
# 2         203           19     46          99    Biology     F
#
#        student_id  student_age      score  attendance
# count    50.00000    50.000000  50.000000   50.000000
# mean    225.50000    18.280000  67.300000   79.580000
# std      14.57738     1.852081  18.248008   12.163998
# min     201.00000    15.000000  41.000000   60.000000
# 25%     213.25000    17.000000  50.000000   68.000000
# 50%     225.50000    18.000000  66.000000   82.000000
# 75%     237.75000    20.000000  83.000000   91.000000
# max     250.00000    21.000000  99.000000   99.000000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   50 non-null     int64
#  1   student_age  50 non-null     int64
#  2   score        50 non-null     int64
#  3   attendance   50 non-null     int64
#  4   department   50 non-null     object
#  5   grade        50 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB
# None

# %%
filterd_dataset  = df.loc[
    (df['student_age'] >= 16) & (df['student_age'] <= 20),
    ['student_id', 'student_age', 'department', 'grade']]
filterd_dataset = filterd_dataset.sort_values(by='student_id')

print(filterd_dataset.tail(3))
# Out:
#     student_id  student_age department grade
# 45         246           18    Biology     C
# 47         248           18    Science     A
# 49         250           17  Economics     F

# %% [markdown]
# # Question 04: [ Marks 10 ]
#
# ##
# Using .loc:
#
# * Increase the score by 10% for students in "Computer Science" and "Mathematics" departments
# * Increase the score by 5% for all other departments
# * Cap the score at 100 (no score should exceed 100 after the raise)
#
# Then print a DataFrame that includes:
#
# * student_id, department, previous_score, new_score, score_increase

# %% [markdown]
# ## Write Answer 04:

# %%
import pandas as pd
df = pd.read_csv("/content/school_data.csv")
df
# Out:
#     student_id  student_age  score  attendance        department grade
# 0          201           21     76          73           Physics     B
# 1          202           18     90          82           Physics     A
# 2          203           19     46          99           Biology     F
# 3          204           21     60          80         Economics     C
# 4          205           17     48          75         Economics     F
# 5          206           19     78          77              Arts     B
# 6          207           19     57          83           Physics     C
# 7          208           21     43          85           Science     F
# 8          209           16     64          84  Computer Science     C
# 9          210           17     99          88  Computer Science     A
# 10         211           21     53          74       Mathematics     C
# 11         212           17     89          60           Physics     A
# 12         213           17     97          84           Physics     A
# 13         214           19     48          66  Computer Science     F
# 14         215           18     65          68           Physics     B
# 15         216           17     92          83              Arts     A
# 16         217           20     41          60           English     F
# 17         218           19     59          67          Commerce     C
# 18         219           16     67          83         Economics     B
# 19         220           18     86          70           Biology     A
# 20         221           20     99          76       Mathematics     A
# 21         222           20     46          67           English     F
# 22         223           16     83          94  Computer Science     A
# 23         224           18     47          94         Economics     F
# 24         225           19     86          92           Physics     A
# 25         226           15     74          64           Biology     B
# 26         227           18     53          98           Physics     C
# 27         228           16     56          87           Science     C
# 28         229           20     75          66           Science     B
# 29         230           19     89          68           Biology     A
# 30         231           18     79          67           Biology     B
# 31         232           15     43          71  Computer Science     F
# 32         233           15     41          93           Biology     F
# 33         234           17     45          92              Arts     F
# 34         235           17     93          82           Physics     A
# 35         236           21     81          83           English     A
# 36         237           16     43          96         Chemistry     F
# 37         238           18     93          94           Biology     A
# 38         239           18     68          99       Mathematics     B
# 39         240           21     57          81           Science     C
# 40         241           20     65          86              Arts     B
# 41         242           20     83          94         Economics     A
# 42         243           21     73          60         Chemistry     B
# 43         244           20     49          94           English     F
# 44         245           17     75          96         Chemistry     B
# 45         246           18     53          73           Biology     C
# 46         247           21     70          62  Computer Science     B
# 47         248           18     87          60           Science     A
# 48         249           15     54          64           Science     C
# 49         250           17     47          85         Economics     F

# %%
df['previous_score'] = df['score']

score_1 = df.loc[df['department'].str.contains(r'Computer|Math'), 'score'] * 0.10

score_2 = df.loc[~df['department'].str.contains(r'Computer|Math'), 'score'] * 0.05

df.loc[df['department'].str.contains(r'Computer|Math'),'score'] += score_1

df.loc[~df['department'].str.contains(r'Computer|Math'), 'score'] += score_2

df['score'] = df['score'].clip(upper=100)

df['new_score'] = df['score']

df['score_increase'] = df['new_score'] - df['previous_score']
print(df[['student_id','department', 'previous_score', 'new_score', 'score_increase']])
# Out:
#     student_id        department  previous_score  new_score  score_increase
# 0          201           Physics              76      79.80            3.80
# 1          202           Physics              90      94.50            4.50
# 2          203           Biology              46      48.30            2.30
# 3          204         Economics              60      63.00            3.00
# 4          205         Economics              48      50.40            2.40
# 5          206              Arts              78      81.90            3.90
# 6          207           Physics              57      59.85            2.85
# 7          208           Science              43      45.15            2.15
# 8          209  Computer Science              64      70.40            6.40
# 9          210  Computer Science              99     100.00            1.00
# 10         211       Mathematics              53      58.30            5.30
# 11         212           Physics              89      93.45            4.45
# 12         213           Physics              97     100.00            3.00
# 13         214  Computer Science              48      52.80            4.80
# 14         215           Physics              65      68.25            3.25
# 15         216              Arts              92      96.60            4.60
# 16         217           English              41      43.05            2.05
# 17         218          Commerce              59      61.95            2.95
# 18         219         Economics              67      70.35            3.35
# 19         220           Biology              86      90.30            4.30
# 20         221       Mathematics              99     100.00            1.00
# 21         222           English              46      48.30            2.30
# 22         223  Computer Science              83      91.30            8.30
# 23         224         Economics              47      49.35            2.35
# 24         225           Physics              86      90.30            4.30
# 25         226           Biology              74      77.70            3.70
# 26         227           Physics              53      55.65            2.65
# 27         228           Science              56      58.80            2.80
# 28         229           Science              75      78.75            3.75
# 29         230           Biology              89      93.45            4.45
# 30         231           Biology              79      82.95            3.95
# 31         232  Computer Science              43      47.30            4.30
# 32         233           Biology              41      43.05            2.05
# 33         234              Arts              45      47.25            2.25
# 34         235           Physics              93      97.65            4.65
# 35         236           English              81      85.05            4.05
# 36         237         Chemistry              43      45.15            2.15
# 37         238           Biology              93      97.65            4.65
# 38         239       Mathematics              68      74.80            6.80
# 39         240           Science              57      59.85            2.85
# 40         241              Arts              65      68.25            3.25
# 41         242         Economics              83      87.15            4.15
# 42         243         Chemistry              73      76.65            3.65
# 43         244           English              49      51.45            2.45
# 44         245         Chemistry              75      78.75            3.75
# 45         246           Biology              53      55.65            2.65
# 46         247  Computer Science              70      77.00            7.00
# 47         248           Science              87      91.35            4.35
# 48         249           Science              54      56.70            2.70
# 49         250         Economics              47      49.35            2.35
# /tmp/ipykernel_6528/2385360744.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 70.4 108.9  58.3  52.8 108.9  91.3  47.3  74.8  77. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['department'].str.contains(r'Computer|Math'),'score'] += score_1

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# Using Matplotlib, create a bar chart that shows the average score per department.
#
# * X-axis: Department names
# * Y-axis: Average score
# * Add a title: "Average Score by Department"
# * Display the chart

# %% [markdown]
# ## Answer 05:

# %%
average_score = df.groupby('department')['score'].mean()
plt.xlabel('Department names')
plt.ylabel('Average score')
plt.title('Average Score by Department')
colors = np.random.rand(50, 3)
plt.bar(average_score.index,average_score .values,color = colors,edgecolor = 'black')
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# Using Matplotlib, create a histogram of the score column.
#
# * Use 10 bins
# * Add a title: "Distribution of Student Scores"
# * Label X-axis as "Score" and Y-axis as "Number of Students"
# * Display the chart

# %% [markdown]
# ## Answer 06:

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.xlabel('Score')
plt.ylabel('Numbers of Students')
plt.title('Distribution of Student Scores')

plt.hist(df['score'],bins = 10,color = '#9637f0',edgecolor ='black')
# Out:
# (array([8., 5., 7., 2., 4., 3., 5., 3., 6., 7.]),
#  array([ 43.05 ,  48.745,  54.44 ,  60.135,  65.83 ,  71.525,  77.22 ,
#          82.915,  88.61 ,  94.305, 100.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Question 07: [ Marks 10 ]
#
# Using Matplotlib, create a scatter plot to visualize the relationship between attendance and score.
#
# * X-axis: Attendance (%)
# * Y-axis: Score
# * Add a title: "Attendance vs Score"
# * Label both axes properly
# * Display the chart

# %% [markdown]
# ## Answer 07:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.xlabel('Attendance(%)')
plt.ylabel('Score')
plt.title('Attendance vs Score')
colors = np.random.rand(50, 3)

plt.scatter(df['attendance'],df['score'],color = colors)

# %% [markdown]
# # Question 08: [ Marks 10 ]
#
# Using Seaborn, create a boxplot that shows the distribution of score across different grade categories.
#
# * X-axis: Grade
# * Y-axis: Score
# * Add a title: "Score Distribution by Grade"
# * Display the chart

# %% [markdown]
# ## Answer 08:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/school_data.csv')

plt.title('Score Distribution by Grade')
sns.boxplot( data = df,x = 'grade',y = 'score',color='red')
plt.show()

# %% [markdown]
# # Question 09: [ Marks 10 ]
#
# Using Seaborn, create a countplot showing the number of students in each department.
#
# * Add a title: "Number of Students per Department"
# * Display the chart

# %% [markdown]
# # Write Answer 09:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/school_data.csv')
plt.title('Number of Students per Department')

colors = np.random.rand(10, 3)
sns.countplot(data = df,x = 'department',palette=colors,edgecolor = 'black' )

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_6528/1317365813.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df,x = 'department',palette=colors,edgecolor = 'black' )
# /tmp/ipykernel_6528/1317365813.py:8: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.countplot(data = df,x = 'department',palette=colors,edgecolor = 'black' )

# %% [markdown]
# # Question 10: [ Marks 10 ]
#
# create a scatter plot showing attendance vs score.
#
# * Color the points by department
# * Add a title: "Attendance vs Score by Department"
# * Label X-axis as "Attendance (%)" and Y-axis as "Score"
# * Display the chart

# %% [markdown]
# # Write Answer 10:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/school_data.csv')
plt.title('Attendance vs Score by Department')
sns.scatterplot(data=df, x='attendance', y='score', hue='department')

# sns.relplot(kind = 'scatter' ,data=df, x='attendance', y='score', hue='department' )

# relplot use korle ekta problem face kori,2 ta figure ashe, ekta blank , sejnno direct scatterplot use korechi

plt.show()
