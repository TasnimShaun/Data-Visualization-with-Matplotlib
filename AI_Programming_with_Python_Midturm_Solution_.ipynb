# %% [markdown]
# <a href="https://colab.research.google.com/github/TasnimShaun/Data-Visualization-with-Matplotlib/blob/main/AI_Programming_with_Python_Midturm_Solution_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# registered email : tasnimshaun3@gmail.com

# %%
import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# Question:01

# %%
import numpy as np
import pandas as pd

emp_ages = np.array(data['emp_age'])
emp_salary = np.array(data['emp_salary'])
print(f"Employee ages Array :{emp_ages}")
print()
print(f"Employee salaray Array :{emp_salary}")
# Out:
# Employee ages Array :[54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
#
# Employee salaray Array :[51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]

# %%
# employee age information
print("employee age information:")
print("data type:",emp_ages.dtype)
print("shape:",emp_ages.shape)
print(f"dimention:{emp_ages.ndim}D ")
print("total number of element:",emp_ages.size)

print()

# employee salary information
print("employee salary information:")
print("data type:",emp_salary.dtype)
print("shape:",emp_salary.shape)
print(f"dimention:{emp_salary.ndim}D ")
print("total number of element:",emp_salary.size)
# Out:
# employee age information:
# data type: int64
# shape: (50,)
# dimention:1D
# total number of element: 50
#
# employee salary information:
# data type: int64
# shape: (50,)
# dimention:1D
# total number of element: 50

# %% [markdown]
# Question: 02

# %%
#max and min salary

maximum_salary = np.max(emp_salary)
minimum_salary = np.min(emp_salary)

# average salary

average_salary = np.mean(emp_salary)

# average age
average_age = np.mean(emp_ages)

print("Maximum Salary:", maximum_salary)
print("Minimum Salary:", minimum_salary)
print("Average Salary:", average_salary)
print("Average Age:", average_age)
# Out:
# Maximum Salary: 94722
# Minimum Salary: 35452
# Average Salary: 68409.48
# Average Age: 35.44

# %% [markdown]
# Question: 03

# %%
employees = data[(emp_ages >= 25) & (emp_ages <= 40) & (emp_salary > 50000)]

print("Filtered Employee:")
print()
print(employees)
print()

count = employees.shape[0]
print(f"Number of employees satisfying the condition: {count}")
# Out:
# Filtered Employee:
#
#     emp_id  emp_age  emp_salary                role
# 4      105       37       72187   Backend Developer
# 5      106       37       58915          HR Manager
# 7      108       35       92864     Sales Executive
# 9      110       38       90494        HR Executive
# 10     111       31       68641   Backend Developer
# 12     113       29       56879     Sales Executive
# 13     114       38       83682  Operations Manager
# 14     115       27       94722    Digital Marketer
# 19     120       32       74146   Backend Developer
# 23     124       26       78354  Software Developer
# 25     126       37       79898  Operations Manager
# 26     127       26       59682    Digital Marketer
# 29     130       30       73700          Accountant
# 37     138       30       84188          Accountant
# 38     139       27       52013          HR Manager
# 39     140       25       63326     Sales Executive
# 48     149       31       59727    Digital Marketer
#
# ...

# %% [markdown]
# Question: 04

# %%
average_age = np.mean(emp_ages)
# print(average_age)
new_employee_age = np.where(emp_ages < average_age,emp_ages + 4,emp_ages + 2)
print("Original Age Array :",np.array(emp_ages))

print()

print("Updated Age Array :",new_employee_age)

print()

new_average_age = np.mean(new_employee_age)

print("new average age :", new_average_age)
# Out:
# 35.44
# Original Age Array : [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
#
# Updated Age Array :  [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
#
# new average age : 38.48

# %% [markdown]
# Question:05

# %%
old_total_salary = np.sum(data['emp_salary'])
tech = ['Software Developer', 'Backend Developer', 'Digital Marketer']

new_salary = np.where(
    data['role'].isin(tech),data['emp_salary'] * 1.08,
    data['emp_salary']
)
new_total_salary = np.sum(new_salary)

difference = new_total_salary - old_total_salary
print(f"old total salary : {old_total_salary}")
print(f"new total salary : {new_total_salary}")
print(f"difference : {difference}")
# Out:
# old total salary : 3420474
# new total salary : 3524808.08
# difference : 104334.08000000007

# %% [markdown]
# Question:06

# %%
import pandas as pd
df = pd.read_csv("staff_data.csv")
print(df.head(3))
print()
print(df.describe())
print()
print(df.info())
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
#
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# max    150.00000  54.000000  94722.000000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# ...

# %% [markdown]
# Qustion: 07

# %%
#filter dataset

filtered = df.loc[(df['emp_age'] >= 25) & (df['emp_age'] <= 40),
    ['emp_id', 'emp_age', 'role']
]

filtered = filtered.sort_values('emp_id', ascending=0)

print(filtered.tail(3))
# Out:
#    emp_id  emp_age               role
# 7     108       35    Sales Executive
# 5     106       37         HR Manager
# 4     105       37  Backend Developer

# %% [markdown]
# Question: 08

# %%
filter_by_HR = df.loc[df['role'].str.contains('HR') ]
print(filter_by_HR)
print()
number = filter_by_HR.shape[0]
print(f"total number of HR employees: {number}")
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
#
# total number of HR employees: 9

# %% [markdown]
# Question:09

# %%
sorted_dataframe = df.sort_values( ['emp_age','emp_salary'],ascending=[0,1] )
display = sorted_dataframe[['emp_id','role','emp_salary']]
print(display.head(5))
# Out:
#     emp_id                role  emp_salary
# 0      101          HR Manager       51725
# 47     148  Software Developer       73048
# 21     122     Sales Executive       47678
# 24     125        HR Executive       60584
# 33     134   Backend Developer       72269

# %% [markdown]
# Question: 10

# %%
df['previous_salary'] = df['emp_salary']

salary_1 = df.loc[df['role'].isin(['Software Developer', 'Backend Developer']), 'emp_salary'] * 0.12

salary_2 = df.loc[~df['role'].isin(['Software Developer', 'Backend Developer']), 'emp_salary'] * 0.05

df.loc[df['role'].isin(['Software Developer', 'Backend Developer']), 'emp_salary'] += salary_1

df.loc[~df['role'].isin(['Software Developer', 'Backend Developer']), 'emp_salary'] += salary_2

df['new_salary'] = df['emp_salary']

df['increase_of_salary'] = df['new_salary'] - df['previous_salary']

print(df[['role', 'previous_salary', 'new_salary', 'increase_of_salary']])
# Out:
#                    role  previous_salary  new_salary  increase_of_salary
# 0            HR Manager            51725    54311.25             2586.25
# 1            Accountant            38495    40419.75             1924.75
# 2    Operations Manager            35452    37224.60             1772.60
# 3      Digital Marketer            82295    86409.75             4114.75
# 4     Backend Developer            72187    80849.44             8662.44
# 5            HR Manager            58915    61860.75             2945.75
# 6     Backend Developer            76159    85298.08             9139.08
# 7       Sales Executive            92864    97507.20             4643.20
# 8       Sales Executive            76155    79962.75             3807.75
# 9          HR Executive            90494    95018.70             4524.70
# 10    Backend Developer            68641    76877.92             8236.92
# 11  Marketing Executive            48079    50482.95             2403.95
# ...

# %%
import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)
